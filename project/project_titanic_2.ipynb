# %%
# import libraries
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Input
from mpl_toolkits.mplot3d import Axes3D
from numpy import arange

import tensorflow as tf
import keras
from keras import layers, models

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import median_absolute_error, mean_absolute_percentage_error

from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
# Function to create a new model
def create_model(features, num_layers=3, units=200, activation='sigmoid'):
    model = keras.Sequential()
    model.add(keras.layers.InputLayer(shape=(features,)))  # Set to the number of features
    
    # Dense layers
    for _ in range(num_layers):
        model.add(keras.layers.Dense(units, activation=activation))
    
    model.add(keras.layers.Dense(1, activation='sigmoid'))  # Output layer for regression / changed from linear to sigmoid for binary
    return model

def clean_data(data_set):
    # Convert 'Sex' to numeric (male = 0, female = 1)
    data_set['Sex'] = data_set['Sex'].map({'male': 0, 'female': 1}) # i learned how to map String to numbers

    # Handle missing values in 'Age' and 'Fare' by filling median
    data_set['Age'] = data_set['Age'].fillna(data_set['Age'].median()) # i learned to fill na with median
    data_set['Fare'] = data_set['Fare'].fillna(data_set['Fare'].median())
    return data_set

# %%
# read train.csv data file
train_data = pd.read_csv('train.csv')
print(f'train {len(train_data.index)} instances')
# read test.csv data file
    ### unused (cant evaluate)
    # test_data = pd.read_csv('test.csv')
    # print(f'test {len(test_data.index)} instances')
print('<< read successfully >>')
# Out:
# train 891 instances
# << read successfully >>

# %%
# show data
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
## model 1
# Select relevant columns
features = ['Pclass', 'Sex', 'Age', 'Fare', 'SibSp', 'Parch']
target = 'Survived'

# Filter the data based on features and target
filtered_data = train_data[features + [target]]
clean_data(filtered_data)

    # filtered_test_data = test_data[features]
    # clean_data(filtered_test_data)
# Print
filtered_data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3384\207283920.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['Sex'] = data_set['Sex'].map({'male': 0, 'female': 1}) # i learned how to map String to numbers
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3384\207283920.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['Age'] = data_set['Age'].fillna(data_set['Age'].median()) # i learned to fill na with median
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3384\207283920.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_set['Fare'] = data_set['Fare'].fillna(data_set['Fare'].median())
#      Pclass  Sex   Age     Fare  SibSp  Parch  Survived
# 0         3    0  22.0   7.2500      1      0         0
# 1         1    1  38.0  71.2833      1      0         1
# 2         3    1  26.0   7.9250      0      0         1
# 3         1    1  35.0  53.1000      1      0         1
# 4         3    0  35.0   8.0500      0      0         0
# ..      ...  ...   ...      ...    ...    ...       ...
# 886       2    0  27.0  13.0000      0      0         0
# 887       1    1  19.0  30.0000      0      0         1
# 888       3    1  28.0  23.4500      1      2         0
# 889       1    0  26.0  30.0000      0      0         1
# 890       3    0  32.0   7.7500      0      0         0
#
# [891 rows x 7 columns]

# %%
# Drawing bar graph
# Calculate survival rates based on 'Sex' and 'Pclass'
survival_rates = filtered_data.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()

# Plotting
plt.figure(figsize=(10, 6))
survival_rates.plot(kind='bar', color=['blue', 'pink'], alpha=0.7)
plt.title('Survival Rates by Class and Gender')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.legend(title='Sex', labels=['Male', 'Female'])
plt.ylim(0, 1)  # Set y-axis limits from 0 to 1 for better readability
plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# creating model
tf.keras.backend.clear_session() # reset session
model = create_model(len(features))
print("Model 2")
print(model.summary())
# Out:
# Model 2
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 200)            │         1,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 200)            │        40,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,001 (320.32 KB)
#  Trainable params: 82,001 (320.32 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# training models

# Train setup
loss = 'binary_crossentropy'  # switch to binary
metric = 'accuracy'  # switch to accuracy
epochs = 200  # number of epochs

# Split Data
x_train, x_val, y_train, y_val = train_test_split(filtered_data[features], filtered_data[target], test_size=0.2, random_state=42)

# Train
model.compile(loss=loss, optimizer='adam', metrics=[metric])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(x_train, y_train, epochs=epochs, batch_size=64, verbose=1, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.6264 - loss: 0.6539 - val_accuracy: 0.6704 - val_loss: 0.6113
# Epoch 2/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6629 - loss: 0.6172 - val_accuracy: 0.7598 - val_loss: 0.5948
# Epoch 3/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6465 - loss: 0.6516 - val_accuracy: 0.6760 - val_loss: 0.6138
# Epoch 4/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6617 - loss: 0.6436 - val_accuracy: 0.6927 - val_loss: 0.5769
# Epoch 5/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6694 - loss: 0.6167 - val_accuracy: 0.7374 - val_loss: 0.5804
# Epoch 6/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6557 - loss: 0.6448 - val_accuracy: 0.6034 - val_loss: 0.6358
# Epoch 7/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6644 - loss: 0.6137 - val_accuracy: 0.7263 - val_loss: 0.5795
# Epoch 8/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6819 - loss: 0.6112 - val_accuracy: 0.6816 - val_loss: 0.5785
# Epoch 9/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6694 - loss: 0.6065 - val_accuracy: 0.7207 - val_loss: 0.5646
# Epoch 10/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6816 - loss: 0.6097 - val_accuracy: 0.6872 - val_loss: 0.5732
# Epoch 11/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6702 - loss: 0.6036 - val_accuracy: 0.6927 - val_loss: 0.5708
# Epoch 12/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6905 - loss: 0.5917 - val_accuracy: 0.7263 - val_loss: 0.5683
# Epoch 13/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6648 - loss: 0.6147 - val_accuracy: 0.7095 - val_loss: 0.5795
# Epoch 14/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6947 - loss: 0.5980 - val_accuracy: 0.7151 - val_loss: 0.5598
# Epoch 15/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6966 - loss: 0.5815 - val_accuracy: 0.7207 - val_loss: 0.5555
# Epoch 16/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7045 - loss: 0.5736 - val_accuracy: 0.7095 - val_loss: 0.5468
# Epoch 17/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6867 - loss: 0.5836 - val_accuracy: 0.7318 - val_loss: 0.5403
# Epoch 18/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7028 - loss: 0.5638 - val_accuracy: 0.7318 - val_loss: 0.5270
# Epoch 19/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7126 - loss: 0.5493 - val_accuracy: 0.7430 - val_loss: 0.5163
# Epoch 20/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7131 - loss: 0.5605 - val_accuracy: 0.7430 - val_loss: 0.5228
# Epoch 21/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7195 - loss: 0.5511 - val_accuracy: 0.7318 - val_loss: 0.5313
# Epoch 22/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7303 - loss: 0.5237 - val_accuracy: 0.7318 - val_loss: 0.5080
# Epoch 23/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7597 - loss: 0.5091 - val_accuracy: 0.7765 - val_loss: 0.4710
# Epoch 24/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7452 - loss: 0.4996 - val_accuracy: 0.7709 - val_loss: 0.4622
# Epoch 25/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7732 - loss: 0.4839 - val_accuracy: 0.7654 - val_loss: 0.4457
# Epoch 26/300
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.